# %% [markdown]
# ## Importing JIGSAWS dataset

# %%
# !mkdir jigsaws
# %cd jigsaws
# !pwd
# Out:
# /content/jigsaws
# /content/jigsaws

# %%
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Knot_Tying.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Needle_Passing.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Suturing.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Experimental_setup.zip
# Out:
# --2022-11-03 10:57:23--  https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Knot_Tying.zip
# Resolving cs.jhu.edu (cs.jhu.edu)... 128.220.13.64
# Connecting to cs.jhu.edu (cs.jhu.edu)|128.220.13.64|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Knot_Tying.zip [following]
# --2022-11-03 10:57:24--  https://www.cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Knot_Tying.zip
# Resolving www.cs.jhu.edu (www.cs.jhu.edu)... 128.220.13.64
# Connecting to www.cs.jhu.edu (www.cs.jhu.edu)|128.220.13.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73622618 (70M) [application/zip]
# Saving to: ‘Knot_Tying.zip’
#
# Knot_Tying.zip      100%[===================>]  70.21M  13.6MB/s    in 6.7s
#
# 2022-11-03 10:57:32 (10.5 MB/s) - ‘Knot_Tying.zip’ saved [73622618/73622618]

# %%
from IPython.display import clear_output
# !unzip -o Knot_Tying.zip -d jigsaws
# !unzip -o Needle_Passing.zip -d jigsaws
# !unzip -o Suturing.zip -d jigsaws
# !unzip -o Experimental_setup.zip -d jigsaws
# clear_output()
# Out:
# Archive:  Knot_Tying.zip
#    creating: jigsaws/Knot_Tying/
#   inflating: jigsaws/Knot_Tying/readme.txt
#   inflating: jigsaws/Knot_Tying/meta_file_Knot_Tying.txt
#    creating: jigsaws/Knot_Tying/transcriptions/
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_B001.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_B002.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_B003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_B004.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_C001.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_C002.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_C003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_C004.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_C005.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_D001.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_D002.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_D003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_D004.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_D005.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_E001.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_E002.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_E003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_E004.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_E005.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_F001.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_F002.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_F003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_F004.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_F005.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_G001.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_G002.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_G003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_G004.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_G005.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_H003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_H004.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_H005.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_I001.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_I002.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_I003.txt
#   inflating: jigsaws/Knot_Tying/transcriptions/Knot_Tying_I005.txt
#    creating: jigsaws/Knot_Tying/video/
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B001_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B002_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B002_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B004_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B004_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C001_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C001_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C002_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C002_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C004_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C004_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C005_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_C005_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D001_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D001_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D002_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D002_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D004_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D004_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D005_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_D005_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E001_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E001_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E002_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E002_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E004_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E004_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E005_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_E005_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F001_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F001_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F002_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F002_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F004_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F004_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F005_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_F005_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G001_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G001_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G002_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G002_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G004_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G004_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G005_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_G005_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_H003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_H003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_H004_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_H004_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_H005_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_H005_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I001_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I001_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I002_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I002_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I003_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I003_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I005_capture1.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_I005_capture2.avi
#   inflating: jigsaws/Knot_Tying/video/Knot_Tying_B001_capture1.avi
#    creating: jigsaws/Knot_Tying/kinematics/
#    creating: jigsaws/Knot_Tying/kinematics/AllGestures/
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_B001.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_B002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_B003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_B004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_B005.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_C001.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_C002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_C003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_C004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_C005.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_D001.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_D002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_D003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_D004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_D005.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_E001.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_E002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_E003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_E004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_E005.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_F001.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_F002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_F003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_F004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_F005.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_G001.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_G002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_G003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_G004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_G005.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_H001.txt
#  extracting: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_H002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_H003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_H004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_H005.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_I001.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_I002.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_I003.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_I004.txt
#   inflating: jigsaws/Knot_Tying/kinematics/AllGestures/Knot_Tying_I005.txt
#   inflating: jigsaws/Knot_Tying/.DS_Store

# %% [markdown]
# ## Required Libraries

# %%
from tensorflow import keras
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2
import os

# %% [markdown]
# ## Define hyperparameters

# %%
IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 10
MAX_SEQ_LENGTH = 20
NUM_FEATURES = 2048
EXP_TYPE = 'Knot_Tying'
ROOT_DIR = '/content/jigsaws/jigsaws'
COLNAMES = ['video_name','tag']

# %% [markdown]
# ## Data preparation

# %%
def getSkills():
  skills = {}
  with open(os.path.join(ROOT_DIR,EXP_TYPE,f'meta_file_{EXP_TYPE}.txt'),'r') as f:
    for line in f.readlines()[:-1]:
      l = (line.strip()).split("\t")
      skills[l[0]] = l[2]
  return skills

# %%
def getMetadata():
  data = []
  skills = getSkills()
  videos = os.listdir(os.path.join(ROOT_DIR,EXP_TYPE,'video'));
  print(f"Total videos in {EXP_TYPE}: ",len(videos))
  for vid in videos:
    l = vid.split('_')
    data.append(
        [vid,skills[l[0]+"_"+l[1]+"_"+l[2]]]
    )
  return pd.DataFrame(data = data,columns = COLNAMES)

# %%
data = getMetadata()
# Out:
# Total videos in Knot_Tying:  72

# %%
data.head()
# Out:
#                      video_name tag
# 0  Knot_Tying_I001_capture1.avi   N
# 1  Knot_Tying_I002_capture1.avi   N
# 2  Knot_Tying_H004_capture2.avi   N
# 3  Knot_Tying_F002_capture2.avi   I
# 4  Knot_Tying_G003_capture1.avi   N

# %% [markdown]
# ### Stratified sampling of videos

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_indices,test_indices in sss.split(data.iloc[:,0],data.iloc[:,1]):
  train_df = data.iloc[train_indices]
  test_df = data.iloc[test_indices]

# %%
train_df['tag'].value_counts()
# Out:
# N    25
# E    16
# I    16
# Name: tag, dtype: int64

# %%
test_df['tag'].value_counts()
# Out:
# N    7
# I    4
# E    4
# Name: tag, dtype: int64

# %%
print(f"Total videos for training: {len(train_df)}")
print(f"Total videos for testing: {len(test_df)}")

train_df.sample(10)
# Out:
# Total videos for training: 57
# Total videos for testing: 15
#                       video_name tag
# 16  Knot_Tying_I002_capture2.avi   N
# 26  Knot_Tying_E001_capture1.avi   E
# 43  Knot_Tying_C002_capture2.avi   I
# 71  Knot_Tying_B003_capture2.avi   N
# 61  Knot_Tying_F001_capture1.avi   I
# 6   Knot_Tying_D003_capture1.avi   E
# 46  Knot_Tying_D002_capture2.avi   E
# 7   Knot_Tying_E002_capture1.avi   E
# 30  Knot_Tying_G002_capture2.avi   N
# 22  Knot_Tying_F003_capture2.avi   I

# %% [markdown]
# **Workflow**
#
# 1. Capture the frames of a video.
# 2. Extract frames from the videos until a maximum frame count is reached.
# 3. In the case, where a video's frame count is lesser than the maximum frame count we
# will pad the video with zeros.

# %% [markdown]
# We can use a pre-trained network **Inception V3** to extract meaningful features from the extracted
# frames.

# %%
def build_feature_extractor():
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step

# %% [markdown]
# The labels of the videos are strings. Neural networks do not understand string values,
# so they must be converted to some numerical form before they are fed to the model. Here
# we will use the [`StringLookup`](https://keras.io/api/layers/preprocessing_layers/categorical/string_lookup)
# layer encode the class labels as integers.

# %%
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"])
)
print(label_processor.get_vocabulary())
# Out:
# ['E', 'I', 'N']

# %% [markdown]
# Finally, we can put all the pieces together to create our data processing utility.

# %%
def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]


def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

# %%
def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = df["tag"].values
    labels = label_processor(labels[..., None]).numpy()

    # `frame_masks` and `frame_features` are what we will feed to our sequence model.
    # `frame_masks` will contain a bunch of booleans denoting if a timestep is
    # masked with padding or not.
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for idx, path in enumerate(video_paths):
        # Gather all its frames and add a batch dimension.
        frames = load_video(os.path.join(root_dir, path))
        frames = frames[None, ...]

        # Initialize placeholders to store the masks and features of the current video.
        temp_frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                temp_frame_features[i, j, :] = feature_extractor.predict(
                    batch[None, j, :]
                )
            temp_frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

        frame_features[idx,] = temp_frame_features.squeeze()
        frame_masks[idx,] = temp_frame_mask.squeeze()

    return (frame_features, frame_masks), labels


train_data, train_labels = prepare_all_videos(train_df, os.path.join(ROOT_DIR,EXP_TYPE,'video'))
test_data, test_labels = prepare_all_videos(test_df, os.path.join(ROOT_DIR,EXP_TYPE,'video'))

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
# Out:
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# ...
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# Frame features in train set: (57, 20, 2048)
# Frame masks in train set: (57, 20)

# %% [markdown]
# ## The sequence model
#
# Now, we can feed this data to a sequence model consisting of recurrent layers like `GRU`.

# %%
def get_sequence_model():
    class_vocab = label_processor.get_vocabulary()

    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    x = keras.layers.GRU(16, return_sequences=True)(
        frame_features_input, mask=mask_input
    )
    x = keras.layers.GRU(8)(x)
    x = keras.layers.Dropout(0.4)(x)
    x = keras.layers.Dense(8, activation="relu")(x)
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

    rnn_model.compile(
        loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
    )
    return rnn_model

# %%
from keras.utils import plot_model
def run_experiment():
    filepath = "/tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    seq_model = get_sequence_model()
    history = seq_model.fit(
        [train_data[0], train_data[1]],
        train_labels,
        validation_split=0.3,
        epochs=100,
        callbacks=[checkpoint],
    )

    seq_model.load_weights(filepath)
    _, accuracy = seq_model.evaluate([test_data[0], test_data[1]], test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, seq_model

history, model = run_experiment()
# Out:
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 8s - loss: 1.1574 - accuracy: 0.3438
# Epoch 1: val_loss improved from inf to 1.11110, saving model to /tmp/video_classifier
# 2/2 [==============================] - 11s 2s/step - loss: 1.1521 - accuracy: 0.3333 - val_loss: 1.1111 - val_accuracy: 0.3889
# Epoch 2/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0581 - accuracy: 0.4688
# Epoch 2: val_loss improved from 1.11110 to 1.10788, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0555 - accuracy: 0.4615 - val_loss: 1.1079 - val_accuracy: 0.3889
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0212 - accuracy: 0.5000
# Epoch 3: val_loss improved from 1.10788 to 1.10358, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0253 - accuracy: 0.5128 - val_loss: 1.1036 - val_accuracy: 0.3889
# Epoch 4/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1528 - accuracy: 0.3438
# Epoch 4: val_loss did not improve from 1.10358
# 2/2 [==============================] - 0s 36ms/step - loss: 1.1405 - accuracy: 0.3846 - val_loss: 1.1064 - val_accuracy: 0.3889
# Epoch 5/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0738 - accuracy: 0.3438
# Epoch 5: val_loss did not improve from 1.10358
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0767 - accuracy: 0.3333 - val_loss: 1.1038 - val_accuracy: 0.3889
# Epoch 6/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0849 - accuracy: 0.4062
# Epoch 6: val_loss improved from 1.10358 to 1.09647, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0586 - accuracy: 0.4615 - val_loss: 1.0965 - val_accuracy: 0.3889
# Epoch 7/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0416 - accuracy: 0.5000
# Epoch 7: val_loss improved from 1.09647 to 1.09498, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0641 - accuracy: 0.4359 - val_loss: 1.0950 - val_accuracy: 0.3889
# Epoch 8/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0651 - accuracy: 0.3750
# Epoch 8: val_loss improved from 1.09498 to 1.09394, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0813 - accuracy: 0.3590 - val_loss: 1.0939 - val_accuracy: 0.3889
# Epoch 9/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0715 - accuracy: 0.4688
# Epoch 9: val_loss improved from 1.09394 to 1.09366, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0738 - accuracy: 0.4872 - val_loss: 1.0937 - val_accuracy: 0.3889
# Epoch 10/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0508 - accuracy: 0.5000
# Epoch 10: val_loss did not improve from 1.09366
# 2/2 [==============================] - 0s 42ms/step - loss: 1.0519 - accuracy: 0.4872 - val_loss: 1.0944 - val_accuracy: 0.3889
# Epoch 11/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0589 - accuracy: 0.4688
# Epoch 11: val_loss did not improve from 1.09366
# 2/2 [==============================] - 0s 40ms/step - loss: 1.0499 - accuracy: 0.4872 - val_loss: 1.0973 - val_accuracy: 0.3889
# Epoch 12/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0574 - accuracy: 0.5938
# Epoch 12: val_loss did not improve from 1.09366
# 2/2 [==============================] - 0s 36ms/step - loss: 1.0647 - accuracy: 0.5641 - val_loss: 1.0973 - val_accuracy: 0.3889
# Epoch 13/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1143 - accuracy: 0.4375
# Epoch 13: val_loss did not improve from 1.09366
# 2/2 [==============================] - 0s 47ms/step - loss: 1.1097 - accuracy: 0.4103 - val_loss: 1.0965 - val_accuracy: 0.3889
# Epoch 14/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0780 - accuracy: 0.5312
# Epoch 14: val_loss improved from 1.09366 to 1.09192, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0655 - accuracy: 0.4872 - val_loss: 1.0919 - val_accuracy: 0.3889
# Epoch 15/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0622 - accuracy: 0.4375
# Epoch 15: val_loss improved from 1.09192 to 1.08858, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0739 - accuracy: 0.3846 - val_loss: 1.0886 - val_accuracy: 0.3889
# Epoch 16/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0299 - accuracy: 0.5312
# Epoch 16: val_loss improved from 1.08858 to 1.08806, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0366 - accuracy: 0.5128 - val_loss: 1.0881 - val_accuracy: 0.3889
# Epoch 17/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0812 - accuracy: 0.3438
# Epoch 17: val_loss improved from 1.08806 to 1.08537, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0772 - accuracy: 0.3590 - val_loss: 1.0854 - val_accuracy: 0.3889
# Epoch 18/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0841 - accuracy: 0.3750
# Epoch 18: val_loss improved from 1.08537 to 1.08295, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0931 - accuracy: 0.3846 - val_loss: 1.0829 - val_accuracy: 0.3889
# Epoch 19/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9847 - accuracy: 0.5625
# Epoch 19: val_loss did not improve from 1.08295
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0009 - accuracy: 0.5128 - val_loss: 1.0847 - val_accuracy: 0.3889
# Epoch 20/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0261 - accuracy: 0.4062
# Epoch 20: val_loss did not improve from 1.08295
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0214 - accuracy: 0.4359 - val_loss: 1.0862 - val_accuracy: 0.3889
# Epoch 21/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0251 - accuracy: 0.4688
# Epoch 21: val_loss did not improve from 1.08295
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0333 - accuracy: 0.4872 - val_loss: 1.0835 - val_accuracy: 0.3889
# Epoch 22/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0377 - accuracy: 0.4688
# Epoch 22: val_loss did not improve from 1.08295
# 2/2 [==============================] - 0s 36ms/step - loss: 1.0405 - accuracy: 0.4872 - val_loss: 1.0834 - val_accuracy: 0.3889
# Epoch 23/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0702 - accuracy: 0.4375
# Epoch 23: val_loss did not improve from 1.08295
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0446 - accuracy: 0.4872 - val_loss: 1.0831 - val_accuracy: 0.3889
# Epoch 24/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0444 - accuracy: 0.5625
# Epoch 24: val_loss did not improve from 1.08295
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0586 - accuracy: 0.5128 - val_loss: 1.0840 - val_accuracy: 0.3889
# Epoch 25/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0470 - accuracy: 0.4688
# Epoch 25: val_loss did not improve from 1.08295
# 2/2 [==============================] - 0s 37ms/step - loss: 1.0463 - accuracy: 0.4615 - val_loss: 1.0836 - val_accuracy: 0.3889
# Epoch 26/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0575 - accuracy: 0.4375
# Epoch 26: val_loss improved from 1.08295 to 1.07884, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0528 - accuracy: 0.4359 - val_loss: 1.0788 - val_accuracy: 0.3889
# Epoch 27/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0647 - accuracy: 0.4688
# Epoch 27: val_loss improved from 1.07884 to 1.07732, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0569 - accuracy: 0.4872 - val_loss: 1.0773 - val_accuracy: 0.3889
# Epoch 28/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0082 - accuracy: 0.5312
# Epoch 28: val_loss improved from 1.07732 to 1.07685, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0224 - accuracy: 0.5128 - val_loss: 1.0768 - val_accuracy: 0.3889
# Epoch 29/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0494 - accuracy: 0.4688
# Epoch 29: val_loss improved from 1.07685 to 1.07674, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0217 - accuracy: 0.5385 - val_loss: 1.0767 - val_accuracy: 0.3889
# Epoch 30/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0354 - accuracy: 0.5000
# Epoch 30: val_loss improved from 1.07674 to 1.07112, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0436 - accuracy: 0.4359 - val_loss: 1.0711 - val_accuracy: 0.3889
# Epoch 31/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9860 - accuracy: 0.5625
# Epoch 31: val_loss improved from 1.07112 to 1.05598, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0048 - accuracy: 0.5128 - val_loss: 1.0560 - val_accuracy: 0.3889
# Epoch 32/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0382 - accuracy: 0.5000
# Epoch 32: val_loss improved from 1.05598 to 1.05005, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0239 - accuracy: 0.5128 - val_loss: 1.0501 - val_accuracy: 0.4444
# Epoch 33/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0169 - accuracy: 0.5312
# Epoch 33: val_loss improved from 1.05005 to 1.04077, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 63ms/step - loss: 0.9950 - accuracy: 0.5641 - val_loss: 1.0408 - val_accuracy: 0.4444
# Epoch 34/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0919 - accuracy: 0.4062
# Epoch 34: val_loss improved from 1.04077 to 1.04044, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0722 - accuracy: 0.4615 - val_loss: 1.0404 - val_accuracy: 0.4444
# Epoch 35/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9885 - accuracy: 0.5625
# Epoch 35: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 42ms/step - loss: 0.9934 - accuracy: 0.5641 - val_loss: 1.0418 - val_accuracy: 0.4444
# Epoch 36/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0092 - accuracy: 0.5625
# Epoch 36: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 37ms/step - loss: 1.0249 - accuracy: 0.5128 - val_loss: 1.0480 - val_accuracy: 0.4444
# Epoch 37/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9965 - accuracy: 0.5938
# Epoch 37: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 36ms/step - loss: 0.9874 - accuracy: 0.5897 - val_loss: 1.0574 - val_accuracy: 0.4444
# Epoch 38/100
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0268 - accuracy: 0.4375
# Epoch 38: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0103 - accuracy: 0.4872 - val_loss: 1.0547 - val_accuracy: 0.4444
# Epoch 39/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9961 - accuracy: 0.5312
# Epoch 39: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 35ms/step - loss: 0.9824 - accuracy: 0.5641 - val_loss: 1.0474 - val_accuracy: 0.5000
# Epoch 40/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9709 - accuracy: 0.5625
# Epoch 40: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 36ms/step - loss: 0.9662 - accuracy: 0.5641 - val_loss: 1.0441 - val_accuracy: 0.4444
# Epoch 41/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9918 - accuracy: 0.5312
# Epoch 41: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 38ms/step - loss: 0.9820 - accuracy: 0.5128 - val_loss: 1.0438 - val_accuracy: 0.4444
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9019 - accuracy: 0.7500
# Epoch 42: val_loss did not improve from 1.04044
# 2/2 [==============================] - 0s 39ms/step - loss: 0.9358 - accuracy: 0.6923 - val_loss: 1.0414 - val_accuracy: 0.4444
# Epoch 43/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9795 - accuracy: 0.6562
# Epoch 43: val_loss improved from 1.04044 to 1.03527, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9714 - accuracy: 0.6410 - val_loss: 1.0353 - val_accuracy: 0.4444
# Epoch 44/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9491 - accuracy: 0.6250
# Epoch 44: val_loss improved from 1.03527 to 1.01943, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 65ms/step - loss: 0.9519 - accuracy: 0.6154 - val_loss: 1.0194 - val_accuracy: 0.5556
# Epoch 45/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9372 - accuracy: 0.6250
# Epoch 45: val_loss improved from 1.01943 to 1.01379, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9536 - accuracy: 0.5641 - val_loss: 1.0138 - val_accuracy: 0.5556
# Epoch 46/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9368 - accuracy: 0.6562
# Epoch 46: val_loss did not improve from 1.01379
# 2/2 [==============================] - 0s 37ms/step - loss: 0.9165 - accuracy: 0.6923 - val_loss: 1.0280 - val_accuracy: 0.5556
# Epoch 47/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9209 - accuracy: 0.6562
# Epoch 47: val_loss did not improve from 1.01379
# 2/2 [==============================] - 0s 35ms/step - loss: 0.9333 - accuracy: 0.6410 - val_loss: 1.0408 - val_accuracy: 0.5000
# Epoch 48/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9517 - accuracy: 0.6562
# Epoch 48: val_loss did not improve from 1.01379
# 2/2 [==============================] - 0s 40ms/step - loss: 0.9389 - accuracy: 0.6667 - val_loss: 1.0330 - val_accuracy: 0.5000
# Epoch 49/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9054 - accuracy: 0.6875
# Epoch 49: val_loss improved from 1.01379 to 1.01250, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 60ms/step - loss: 0.8886 - accuracy: 0.7179 - val_loss: 1.0125 - val_accuracy: 0.5000
# Epoch 50/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9332 - accuracy: 0.6875
# Epoch 50: val_loss improved from 1.01250 to 0.99171, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 60ms/step - loss: 0.9427 - accuracy: 0.6667 - val_loss: 0.9917 - val_accuracy: 0.6667
# Epoch 51/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9022 - accuracy: 0.5938
# Epoch 51: val_loss improved from 0.99171 to 0.97914, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9003 - accuracy: 0.6410 - val_loss: 0.9791 - val_accuracy: 0.6111
# Epoch 52/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9016 - accuracy: 0.6562
# Epoch 52: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9203 - accuracy: 0.6154 - val_loss: 0.9836 - val_accuracy: 0.5556
# Epoch 53/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9076 - accuracy: 0.7188
# Epoch 53: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 36ms/step - loss: 0.8930 - accuracy: 0.7436 - val_loss: 0.9916 - val_accuracy: 0.5556
# Epoch 54/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9020 - accuracy: 0.5938
# Epoch 54: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 42ms/step - loss: 0.8854 - accuracy: 0.6410 - val_loss: 0.9897 - val_accuracy: 0.5556
# Epoch 55/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8335 - accuracy: 0.7188
# Epoch 55: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8489 - accuracy: 0.7179 - val_loss: 1.0072 - val_accuracy: 0.5000
# Epoch 56/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7848 - accuracy: 0.8125
# Epoch 56: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 36ms/step - loss: 0.8150 - accuracy: 0.7692 - val_loss: 1.0062 - val_accuracy: 0.5000
# Epoch 57/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8489 - accuracy: 0.7188
# Epoch 57: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 36ms/step - loss: 0.8709 - accuracy: 0.6923 - val_loss: 0.9929 - val_accuracy: 0.5556
# Epoch 58/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8266 - accuracy: 0.6875
# Epoch 58: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8425 - accuracy: 0.6667 - val_loss: 0.9903 - val_accuracy: 0.5556
# Epoch 59/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9245 - accuracy: 0.6250
# Epoch 59: val_loss did not improve from 0.97914
# 2/2 [==============================] - 0s 39ms/step - loss: 0.8739 - accuracy: 0.6667 - val_loss: 0.9879 - val_accuracy: 0.5556
# Epoch 60/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7889 - accuracy: 0.7188
# Epoch 60: val_loss improved from 0.97914 to 0.95374, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 0.7812 - accuracy: 0.7179 - val_loss: 0.9537 - val_accuracy: 0.6111
# Epoch 61/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8801 - accuracy: 0.5938
# Epoch 61: val_loss improved from 0.95374 to 0.94748, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8516 - accuracy: 0.6410 - val_loss: 0.9475 - val_accuracy: 0.6111
# Epoch 62/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8401 - accuracy: 0.5938
# Epoch 62: val_loss improved from 0.94748 to 0.93583, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8000 - accuracy: 0.6667 - val_loss: 0.9358 - val_accuracy: 0.6111
# Epoch 63/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7652 - accuracy: 0.7188
# Epoch 63: val_loss did not improve from 0.93583
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7722 - accuracy: 0.7179 - val_loss: 0.9792 - val_accuracy: 0.5556
# Epoch 64/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7569 - accuracy: 0.7188
# Epoch 64: val_loss improved from 0.93583 to 0.89798, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7529 - accuracy: 0.7179 - val_loss: 0.8980 - val_accuracy: 0.6667
# Epoch 65/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7057 - accuracy: 0.7500
# Epoch 65: val_loss improved from 0.89798 to 0.88403, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7466 - accuracy: 0.7179 - val_loss: 0.8840 - val_accuracy: 0.6667
# Epoch 66/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7212 - accuracy: 0.7188
# Epoch 66: val_loss did not improve from 0.88403
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7222 - accuracy: 0.7436 - val_loss: 0.9477 - val_accuracy: 0.6111
# Epoch 67/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7818 - accuracy: 0.7812
# Epoch 67: val_loss did not improve from 0.88403
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7864 - accuracy: 0.7436 - val_loss: 0.9778 - val_accuracy: 0.5556
# Epoch 68/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8302 - accuracy: 0.6250
# Epoch 68: val_loss did not improve from 0.88403
# 2/2 [==============================] - 0s 40ms/step - loss: 0.7878 - accuracy: 0.6923 - val_loss: 0.9812 - val_accuracy: 0.5556
# Epoch 69/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7210 - accuracy: 0.7500
# Epoch 69: val_loss did not improve from 0.88403
# 2/2 [==============================] - 0s 40ms/step - loss: 0.7107 - accuracy: 0.7436 - val_loss: 0.9374 - val_accuracy: 0.6111
# Epoch 70/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7336 - accuracy: 0.6562
# Epoch 70: val_loss improved from 0.88403 to 0.85154, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7220 - accuracy: 0.6923 - val_loss: 0.8515 - val_accuracy: 0.6667
# Epoch 71/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6911 - accuracy: 0.7500
# Epoch 71: val_loss did not improve from 0.85154
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6792 - accuracy: 0.7436 - val_loss: 0.8688 - val_accuracy: 0.6667
# Epoch 72/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7646 - accuracy: 0.6875
# Epoch 72: val_loss did not improve from 0.85154
# 2/2 [==============================] - 0s 53ms/step - loss: 0.7592 - accuracy: 0.6923 - val_loss: 0.9524 - val_accuracy: 0.6111
# Epoch 73/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6669 - accuracy: 0.7188
# Epoch 73: val_loss did not improve from 0.85154
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6653 - accuracy: 0.7436 - val_loss: 0.9661 - val_accuracy: 0.5556
# Epoch 74/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6779 - accuracy: 0.7500
# Epoch 74: val_loss did not improve from 0.85154
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6648 - accuracy: 0.7436 - val_loss: 0.9074 - val_accuracy: 0.6111
# Epoch 75/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6458 - accuracy: 0.7500
# Epoch 75: val_loss did not improve from 0.85154
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6364 - accuracy: 0.7692 - val_loss: 0.8865 - val_accuracy: 0.6111
# Epoch 76/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6909 - accuracy: 0.7188
# Epoch 76: val_loss did not improve from 0.85154
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6515 - accuracy: 0.7436 - val_loss: 0.8846 - val_accuracy: 0.5556
# Epoch 77/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6222 - accuracy: 0.7500
# Epoch 77: val_loss improved from 0.85154 to 0.83842, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6546 - accuracy: 0.6923 - val_loss: 0.8384 - val_accuracy: 0.6111
# Epoch 78/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6762 - accuracy: 0.7500
# Epoch 78: val_loss improved from 0.83842 to 0.80461, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6476 - accuracy: 0.7949 - val_loss: 0.8046 - val_accuracy: 0.6667
# Epoch 79/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5907 - accuracy: 0.7812
# Epoch 79: val_loss did not improve from 0.80461
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5690 - accuracy: 0.7949 - val_loss: 0.8305 - val_accuracy: 0.7222
# Epoch 80/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6615 - accuracy: 0.7188
# Epoch 80: val_loss improved from 0.80461 to 0.76546, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6282 - accuracy: 0.7436 - val_loss: 0.7655 - val_accuracy: 0.6667
# Epoch 81/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5227 - accuracy: 0.8125
# Epoch 81: val_loss did not improve from 0.76546
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5379 - accuracy: 0.7949 - val_loss: 0.8084 - val_accuracy: 0.7222
# Epoch 82/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5371 - accuracy: 0.7812
# Epoch 82: val_loss did not improve from 0.76546
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5502 - accuracy: 0.7692 - val_loss: 0.8124 - val_accuracy: 0.6667
# Epoch 83/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5269 - accuracy: 0.8125
# Epoch 83: val_loss did not improve from 0.76546
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5253 - accuracy: 0.7949 - val_loss: 0.8190 - val_accuracy: 0.6667
# Epoch 84/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5709 - accuracy: 0.7812
# Epoch 84: val_loss did not improve from 0.76546
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5311 - accuracy: 0.7949 - val_loss: 0.9210 - val_accuracy: 0.6111
# Epoch 85/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5798 - accuracy: 0.7812
# Epoch 85: val_loss did not improve from 0.76546
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5823 - accuracy: 0.7692 - val_loss: 0.9531 - val_accuracy: 0.5000
# Epoch 86/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5148 - accuracy: 0.7812
# Epoch 86: val_loss did not improve from 0.76546
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4972 - accuracy: 0.7949 - val_loss: 0.9539 - val_accuracy: 0.5000
# Epoch 87/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5225 - accuracy: 0.7812
# Epoch 87: val_loss did not improve from 0.76546
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5071 - accuracy: 0.7949 - val_loss: 0.8157 - val_accuracy: 0.6111
# Epoch 88/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4156 - accuracy: 0.7812
# Epoch 88: val_loss improved from 0.76546 to 0.70935, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4475 - accuracy: 0.7949 - val_loss: 0.7094 - val_accuracy: 0.7222
# Epoch 89/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4628 - accuracy: 0.7500
# Epoch 89: val_loss improved from 0.70935 to 0.68951, saving model to /tmp/video_classifier
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4425 - accuracy: 0.7949 - val_loss: 0.6895 - val_accuracy: 0.7222
# Epoch 90/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4730 - accuracy: 0.9062
# Epoch 90: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4360 - accuracy: 0.8974 - val_loss: 0.7051 - val_accuracy: 0.7222
# Epoch 91/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4402 - accuracy: 0.9062
# Epoch 91: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4135 - accuracy: 0.8974 - val_loss: 0.6971 - val_accuracy: 0.7222
# Epoch 92/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4176 - accuracy: 0.8125
# Epoch 92: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4087 - accuracy: 0.8462 - val_loss: 0.6950 - val_accuracy: 0.7222
# Epoch 93/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4123 - accuracy: 0.9062
# Epoch 93: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3973 - accuracy: 0.9231 - val_loss: 0.7409 - val_accuracy: 0.7222
# Epoch 94/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4883 - accuracy: 0.8438
# Epoch 94: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4704 - accuracy: 0.8462 - val_loss: 0.9142 - val_accuracy: 0.5556
# Epoch 95/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3732 - accuracy: 0.8438
# Epoch 95: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3628 - accuracy: 0.8718 - val_loss: 0.9991 - val_accuracy: 0.6111
# Epoch 96/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.5047 - accuracy: 0.7500
# Epoch 96: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4955 - accuracy: 0.7949 - val_loss: 0.8596 - val_accuracy: 0.6111
# Epoch 97/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4128 - accuracy: 0.7812
# Epoch 97: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3743 - accuracy: 0.8205 - val_loss: 0.7560 - val_accuracy: 0.6667
# Epoch 98/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3253 - accuracy: 0.8750
# Epoch 98: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3429 - accuracy: 0.8974 - val_loss: 0.7135 - val_accuracy: 0.7222
# Epoch 99/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.4356 - accuracy: 0.8750
# Epoch 99: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 52ms/step - loss: 0.3957 - accuracy: 0.8974 - val_loss: 0.7259 - val_accuracy: 0.7222
# Epoch 100/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3101 - accuracy: 0.9688
# Epoch 100: val_loss did not improve from 0.68951
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3838 - accuracy: 0.9231 - val_loss: 0.8133 - val_accuracy: 0.6111
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6277 - accuracy: 0.7333
# Test accuracy: 73.33%

# %%
y_pred = model.predict([test_data[0], test_data[1]])
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
plot_model(model,show_shapes=True)

# %% [markdown]
# ## Inference

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cnf = confusion_matrix(np.squeeze(test_labels),np.argmax(y_pred,axis = 1))
ax= plt.subplot()
sns.heatmap(cnf, annot=True, fmt='g', ax=ax, cmap = 'cividis');  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ticks = label_processor.get_vocabulary()
ax.xaxis.set_ticklabels(ticks); ax.yaxis.set_ticklabels(ticks)
# Out:
# [Text(0, 0.5, 'E'), Text(0, 1.5, 'I'), Text(0, 2.5, 'N')]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc, roc_auc_score

plt.figure(figsize = (12,8))
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
classes = label_processor.get_vocabulary()
n_classes = len(label_processor.get_vocabulary())
y_test = np.squeeze(test_labels)
y_test = label_binarize(y_test,classes = np.unique(y_test))

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

    plt.plot(fpr[i],tpr[i], label = f"{classes[i]} vs Rest  AUC = {roc_auc[i]:.2f}")

plt.plot([0,1],[0,1],'b--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.legend(loc = 'lower right')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()
